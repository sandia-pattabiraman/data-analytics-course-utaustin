# %%
import pandas as pd
import pandas_profiling
import pandas as pd
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport

# %%
credit_csv = pd.read_csv('/Users/ajayvembu/Downloads/Credit_Data.csv',header=1)

# %%
credit_csv.head()
# Out:
#     ID LIMIT_BAL     SEX   EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  \
# 0  1.0     20000  female  university        1  24     2     2    -1    -1
# 1  2.0    120000  female  university        2  26    -1     2     0     0
# 2  3.0     90000  female  university        2  34     0     0     0     0
# 3  4.0     50000  female  university        1  37     0     0     0     0
# 4  5.0     50000    male  university        1  57    -1     0    -1     0
#
#    ... BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4  \
# 0  ...         0         0         0        0      689        0        0
# 1  ...      3272      3455      3261        0     1000     1000     1000
# 2  ...     14331     14948     15549     1518     1500     1000     1000
# 3  ...     28314     28959     29547     2000     2019     1200     1100
# 4  ...     20940     19146     19131     2000    36681    10000     9000
#
#   PAY_AMT5 PAY_AMT6 default payment next month
# ...

# %%
credit_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30001 entries, 0 to 30000
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  float64
#  1   LIMIT_BAL                   30001 non-null  object
#  2   SEX                         30001 non-null  object
#  3   EDUCATION                   30001 non-null  object
#  4   MARRIAGE                    30001 non-null  object
#  5   AGE                         30001 non-null  object
#  6   PAY_0                       30001 non-null  object
#  7   PAY_2                       30001 non-null  object
#  8   PAY_3                       30001 non-null  object
#  9   PAY_4                       30001 non-null  object
#  10  PAY_5                       30001 non-null  object
#  11  PAY_6                       30001 non-null  object
#  12  BILL_AMT1                   30001 non-null  object
# ...

# %%
print(credit_csv.isnull().sum())
# Out:
# ID                            1
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
bool_series = pd.isnull(credit_csv["ID"])

# %%
credit_csv[bool_series]
# Out:
#      ID LIMIT_BAL SEX EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  ...  \
# 201 NaN        X1  X2        X3       X4  X5    X6    X7    X8    X9  ...
#
#     BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4  \
# 201       X15       X16       X17      X18      X19      X20      X21
#
#     PAY_AMT5 PAY_AMT6 default payment next month
# 201      X22      X23                          Y
#
# [1 rows x 25 columns]

# %%
credit_csv=credit_csv.drop(201)

# %%
print(credit_csv.isnull().sum())
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
credit_csv = credit_csv.drop_duplicates()

# %%
credit_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 0 to 30000
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  float64
#  1   LIMIT_BAL                   30000 non-null  object
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   30000 non-null  object
#  4   MARRIAGE                    30000 non-null  object
#  5   AGE                         30000 non-null  object
#  6   PAY_0                       30000 non-null  object
#  7   PAY_2                       30000 non-null  object
#  8   PAY_3                       30000 non-null  object
#  9   PAY_4                       30000 non-null  object
#  10  PAY_5                       30000 non-null  object
#  11  PAY_6                       30000 non-null  object
#  12  BILL_AMT1                   30000 non-null  object
# ...

# %%
pandas_profiling.ProfileReport(credit_csv, minimal=True)
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.11.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-04-18 03:35:13.453670&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
credit_csv['ID'] = credit_csv['ID'].astype(int)

# %%
credit_csv['LIMIT_BAL'] = credit_csv['LIMIT_BAL'].astype(int)

# %%
credit_csv['MARRIAGE'] = credit_csv['MARRIAGE'].astype(int)

# %%
credit_csv['AGE'] = credit_csv['AGE'].astype(int)

# %%
credit_csv['PAY_0'] = credit_csv['PAY_0'].astype(int)

# %%
credit_csv['PAY_2'] = credit_csv['PAY_2'].astype(int)

# %%
credit_csv['PAY_3'] = credit_csv['PAY_3'].astype(int)

# %%
credit_csv['PAY_4'] = credit_csv['PAY_4'].astype(int)

# %%
credit_csv['PAY_5'] = credit_csv['PAY_5'].astype(int)

# %%
credit_csv['PAY_6'] = credit_csv['PAY_6'].astype(int)

# %%
credit_csv['BILL_AMT1'] = credit_csv['BILL_AMT1'].astype(int)

# %%
credit_csv['BILL_AMT2'] = credit_csv['BILL_AMT2'].astype(int)

# %%
credit_csv['BILL_AMT3'] = credit_csv['BILL_AMT3'].astype(int)

# %%
credit_csv['BILL_AMT4'] = credit_csv['BILL_AMT4'].astype(int)

# %%
credit_csv['BILL_AMT5'] = credit_csv['BILL_AMT5'].astype(int)

# %%
credit_csv['BILL_AMT6'] = credit_csv['BILL_AMT6'].astype(int)

# %%
credit_csv['PAY_AMT1'] = credit_csv['PAY_AMT1'].astype(int)

# %%
credit_csv['PAY_AMT2'] = credit_csv['PAY_AMT2'].astype(int)

# %%
credit_csv['PAY_AMT3'] = credit_csv['PAY_AMT3'].astype(int)

# %%
credit_csv['PAY_AMT4'] = credit_csv['PAY_AMT4'].astype(int)

# %%
credit_csv['PAY_AMT5'] = credit_csv['PAY_AMT5'].astype(int)

# %%
credit_csv['PAY_AMT6'] = credit_csv['PAY_AMT6'].astype(int)

# %%
credit_csv.dtypes
# Out:
# ID                             int64
# LIMIT_BAL                      int64
# SEX                           object
# EDUCATION                     object
# MARRIAGE                       int64
# AGE                            int64
# PAY_0                          int64
# PAY_2                          int64
# PAY_3                          int64
# PAY_4                          int64
# PAY_5                          int64
# PAY_6                          int64
# BILL_AMT1                      int64
# BILL_AMT2                      int64
# BILL_AMT3                      int64
# BILL_AMT4                      int64
# BILL_AMT5                      int64
# BILL_AMT6                      int64
# PAY_AMT1                       int64
# PAY_AMT2                       int64
# PAY_AMT3                       int64
# PAY_AMT4                       int64
# PAY_AMT5                       int64
# PAY_AMT6                       int64
# default payment next month    object
# dtype: object

# %%
credit_csv = pd.get_dummies(credit_csv)

# %%
credit_csv.dtypes
# Out:
# ID                                        int64
# LIMIT_BAL                                 int64
# MARRIAGE                                  int64
# AGE                                       int64
# PAY_0                                     int64
# PAY_2                                     int64
# PAY_3                                     int64
# PAY_4                                     int64
# PAY_5                                     int64
# PAY_6                                     int64
# BILL_AMT1                                 int64
# BILL_AMT2                                 int64
# BILL_AMT3                                 int64
# BILL_AMT4                                 int64
# BILL_AMT5                                 int64
# BILL_AMT6                                 int64
# PAY_AMT1                                  int64
# PAY_AMT2                                  int64
# PAY_AMT3                                  int64
# PAY_AMT4                                  int64
# ...

# %%
credit_csv.head()
# Out:
#    ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# 0   1      20000         1   24      2      2     -1     -1     -2     -2
# 1   2     120000         2   26     -1      2      0      0      0      2
# 2   3      90000         2   34      0      0      0      0      0      0
# 3   4      50000         1   37      0      0      0      0      0      0
# 4   5      50000         1   57     -1      0     -1      0      0      0
#
#    ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# 0  ...         0         0           1         0                          0
# 1  ...         0      2000           1         0                          0
# 2  ...      1000      5000           1         0                          0
# 3  ...      1069      1000           1         0                          0
# 4  ...       689       679           0         1                          0
#
# ...

# %%
header = credit_csv.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3',
#        'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3',
#        'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2',
#        'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'SEX_female',
#        'SEX_male', 'EDUCATION_graduate school', 'EDUCATION_high school',
#        'EDUCATION_other', 'EDUCATION_university',
#        'default payment next month_default',
#        'default payment next month_not default'],
#       dtype='object')

# %%
credit_csv.groupby('LIMIT_BAL').count()
# Out:
#              ID  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# LIMIT_BAL
# 10000       493       493   493    493    493    493    493    493    493
# 16000         2         2     2      2      2      2      2      2      2
# 20000      1976      1976  1976   1976   1976   1976   1976   1976   1976
# 30000      1610      1610  1610   1610   1610   1610   1610   1610   1610
# 40000       230       230   230    230    230    230    230    230    230
# ...         ...       ...   ...    ...    ...    ...    ...    ...    ...
# 750000        4         4     4      4      4      4      4      4      4
# 760000        1         1     1      1      1      1      1      1      1
# 780000        2         2     2      2      2      2      2      2      2
# 800000        2         2     2      2      2      2      2      2      2
# 1000000       1         1     1      1      1      1      1      1      1
#
# ...

# %%
credit_csv['LIMIT_BAL_bins'] = pd.cut(x=credit_csv['LIMIT_BAL'], bins=[0, 250000, 500000, 750000, 1000000], labels=[1, 2, 3, 4])

# %%
credit_csv.groupby('LIMIT_BAL_bins').count()
# Out:
#                    ID  LIMIT_BAL  MARRIAGE    AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# LIMIT_BAL_bins
# 1               23283      23283     23283  23283  23283  23283  23283  23283
# 2                6511       6511      6511   6511   6511   6511   6511   6511
# 3                 200        200       200    200    200    200    200    200
# 4                   6          6         6      6      6      6      6      6
#
#                 PAY_5  PAY_6  ...  SEX_female  SEX_male  \
# LIMIT_BAL_bins                ...
# 1               23283  23283  ...       23283     23283
# 2                6511   6511  ...        6511      6511
# 3                 200    200  ...         200       200
# 4                   6      6  ...           6         6
#
#                 EDUCATION_graduate school  EDUCATION_high school  \
# LIMIT_BAL_bins
# 1                                   23283                  23283
# 2                                    6511                   6511
# ...

# %%
#From the data given, most of the defaulters are the ones with credit limit under 250K.
#24% defaulters under 250K vs 14% under 500K vs 11% under 750K vs 0% under 1M. 

credit_csv.loc[(credit_csv[' LIMIT_BAL_bins']==1) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0          1      20000         1   24      2      2     -1     -1     -2
# 1          2     120000         2   26     -1      2      0      0      0
# 13        14      70000         2   30      1      2      2      0      0
# 16        17      20000         2   24      0      0      2      2      2
# 21        22     120000         1   39     -1     -1     -1     -1     -1
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29992  29992     210000         1   34      3      2      2      2      2
# 29995  29995      80000         2   34      2      2      2      2      2
# 29998  29998      30000         2   37      4      3      2     -1      0
# 29999  29999      80000         1   41      1     -1      0      0      0
# 30000  30000      50000         1   46      0      0      0      0      0
#
#        PAY_6  ...  SEX_male  EDUCATION_graduate school  EDUCATION_high school  \
# ...

# %%
credit_csv.loc[(credit_csv[' LIMIT_BAL_bins']==2) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 23        24     450000         1   40     -2     -2     -2     -2     -2
# 60        61     500000         1   28      0      0      0      0      0
# 71        72     320000         2   29      2      2      2      2      2
# 86        87     360000         1   45     -1     -1      2      0     -1
# 121      122     450000         1   40      1     -2     -2     -2     -2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29831  29831     340000         2   33      1     -2     -2     -2     -2
# 29841  29841     320000         1   48      2      2      2      2      2
# 29867  29867     290000         2   30      2      2      0      0      0
# 29879  29879     340000         1   36      0      0      0      0      0
# 29922  29922     410000         2   34      0      0      0     -1     -1
#
#        PAY_6  ...  SEX_male  EDUCATION_graduate school  EDUCATION_high school  \
# ...

# %%
credit_csv.loc[(credit_csv[' LIMIT_BAL_bins']==3) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 452      452     600000         1   53      2      2      0      0      0
# 528      528     620000         1   45      2      2      0      0      0
# 2250    2250     550000         1   32      0      0      0      0      0
# 3340    3340     550000         1   49     -1     -1     -1     -1     -1
# 3403    3403     710000         1   40     -2     -2     -2     -1      2
# 4704    4704     520000         1   41      2      2      0      0      0
# 5287    5287     520000         2   33      0      0      0      0      0
# 10896  10896     630000         2   29      0      0      0      0      0
# 12244  12244     550000         2   34     -1      0      0      0      0
# 13884  13884     740000         1   35      2     -1     -1     -1     -1
# 14084  14084     600000         1   50      0      0      0      0      0
# 15594  15594     600000         1   53      2      2      2      0      0
# ...

# %%
credit_csv.loc[(credit_csv[' LIMIT_BAL_bins']==4) & (credit_csv['default payment next month_default']==1)]
# Out:
# Empty DataFrame
# Columns: [ID, LIMIT_BAL, MARRIAGE, AGE, PAY_0, PAY_2, PAY_3, PAY_4, PAY_5, PAY_6, BILL_AMT1, BILL_AMT2, BILL_AMT3, BILL_AMT4, BILL_AMT5, BILL_AMT6, PAY_AMT1, PAY_AMT2, PAY_AMT3, PAY_AMT4, PAY_AMT5, PAY_AMT6, SEX_female, SEX_male, EDUCATION_graduate school, EDUCATION_high school, EDUCATION_other, EDUCATION_university, default payment next month_default, default payment next month_not default, age_bins,  LIMIT_BAL_bins, LIMIT_BAL_bins]
# Index: []
#
# [0 rows x 33 columns]

# %%
plt.hist(credit_csv['LIMIT_BAL'], bins=5)
# Out:
# (array([2.0378e+04, 7.8180e+03, 1.7250e+03, 7.8000e+01, 1.0000e+00]),
#  array([  10000.,  208000.,  406000.,  604000.,  802000., 1000000.]),
#  <BarContainer object of 5 artists>)

# %%
credit_csv.groupby('SEX_female').count()
# Out:
#                ID  LIMIT_BAL  MARRIAGE    AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# SEX_female
# 0           11888      11888     11888  11888  11888  11888  11888  11888
# 1           18112      18112     18112  18112  18112  18112  18112  18112
#
#             PAY_5  PAY_6  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  SEX_male  \
# SEX_female                ...
# 0           11888  11888  ...     11888     11888     11888     11888
# 1           18112  18112  ...     18112     18112     18112     18112
#
#             EDUCATION_graduate school  EDUCATION_high school  EDUCATION_other  \
# SEX_female
# 0                               11888                  11888            11888
# 1                               18112                  18112            18112
#
#             EDUCATION_university  default payment next month_default  \
# SEX_female
# 0                          11888                               11888
# 1                          18112                               18112
#
# ...

# %%
#From this plot,62% of people are females under 18K.
#Less than 38% of people are males under 11k.

plt.hist(credit_csv['SEX_female'])
plt.show()

# %%
credit_csv.groupby('SEX_male').count()
# Out:
#              ID  LIMIT_BAL  MARRIAGE    AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# SEX_male
# 0         18112      18112     18112  18112  18112  18112  18112  18112
# 1         11888      11888     11888  11888  11888  11888  11888  11888
#
#           PAY_5  PAY_6  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  SEX_female  \
# SEX_male                ...
# 0         18112  18112  ...     18112     18112     18112       18112
# 1         11888  11888  ...     11888     11888     11888       11888
#
#           EDUCATION_graduate school  EDUCATION_high school  EDUCATION_other  \
# SEX_male
# 0                             18112                  18112            18112
# 1                             11888                  11888            11888
#
#           EDUCATION_university  default payment next month_default  \
# SEX_male
# 0                        18112                               18112
# 1                        11888                               11888
#
# ...

# %%
plt.hist(credit_csv['SEX_male'])
plt.show()

# %%
#The proportion of male defaulters is more compared to female defaulters.
#In this data 24% male defaulters whereas 20% female defaulters.

credit_csv.loc[(credit_csv['SEX_female']==1) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0          1      20000         1   24      2      2     -1     -1     -2
# 1          2     120000         2   26     -1      2      0      0      0
# 21        22     120000         1   39     -1     -1     -1     -1     -1
# 22        23      70000         2   26      2      0      0      2      2
# 23        24     450000         1   40     -2     -2     -2     -2     -2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29170  29170      20000         1   56      1      3      2      2      0
# 29171  29171      60000         2   53      1      2      0      0      0
# 29177  29177     240000         1   56      3      2      2     -2     -2
# 29180  29180     500000         1   73     -2     -2     -2     -2     -2
# 29181  29181     140000         1   60      2      2      0      0      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['SEX_female']==1) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 2          3      90000         2   34      0      0      0      0      0
# 3          4      50000         1   37      0      0      0      0      0
# 7          8     100000         2   23      0     -1     -1      0      0
# 8          9     140000         1   28      0      0      2      0      0
# 10        11     200000         2   34      0      0      2      0      0
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29179  29179      90000         2   60     -1     -1     -1      0      0
# 29182  29182     170000         1   57      0      0      0      0      0
# 29183  29183     280000         1   56     -2     -2     -2     -2     -2
# 29186  29186      50000         2   55      2      0      0      0      0
# 29283  29283      80000         3   25      0     -1     -1     -1     -1
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['SEX_male']==1) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 13        14      70000         2   30      1      2      2      0      0
# 16        17      20000         2   24      0      0      2      2      2
# 26        27      60000         2   27      1     -2     -1     -1     -1
# 31        32      50000         2   33      2      0      0      0      0
# 38        39      50000         2   25      1     -1     -1     -2     -2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29992  29992     210000         1   34      3      2      2      2      2
# 29995  29995      80000         2   34      2      2      2      2      2
# 29998  29998      30000         2   37      4      3      2     -1      0
# 29999  29999      80000         1   41      1     -1      0      0      0
# 30000  30000      50000         1   46      0      0      0      0      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['SEX_male']==1) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 4          5      50000         1   57     -1      0     -1      0      0
# 5          6      50000         2   37      0      0      0      0      0
# 6          7     500000         2   29      0      0      0      0      0
# 9         10      20000         2   35     -2     -2     -2     -2     -1
# 14        15     250000         2   29      0      0      0      0      0
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29991  29991     140000         1   41      0      0      0      0      0
# 29993  29993      10000         1   43      0      0      0     -2     -2
# 29994  29994     100000         2   38      0     -1     -1      0      0
# 29996  29996     220000         1   39      0      0      0      0      0
# 29997  29997     150000         2   43     -1     -1     -1     -1      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.groupby('MARRIAGE').count()
# Out:
#              ID  LIMIT_BAL    AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# MARRIAGE
# 0            54         54     54     54     54     54     54     54     54
# 1         13659      13659  13659  13659  13659  13659  13659  13659  13659
# 2         15964      15964  15964  15964  15964  15964  15964  15964  15964
# 3           323        323    323    323    323    323    323    323    323
#
#           BILL_AMT1  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# MARRIAGE             ...
# 0                54  ...        54        54          54        54
# 1             13659  ...     13659     13659       13659     13659
# 2             15964  ...     15964     15964       15964     15964
# 3               323  ...       323       323         323       323
#
#           EDUCATION_graduate school  EDUCATION_high school  EDUCATION_other  \
# MARRIAGE
# 0                                54                     54               54
# ...

# %%
#From this plot,50% of people are single under 15K,43% of people are married under 13K.
#Less than 0.01% of people are divorced and others category.

plt.hist(credit_csv['MARRIAGE'])
plt.show()

# %%
#The proprtion of divorced defaulters is more compared to all the other defaulters.
#In this data 26% divorced defaulters vs 23 % married defaulters vs 20% single defaulters vs 9% other defaulter.

credit_csv.loc[(credit_csv['MARRIAGE']==0) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 8887    8887      70000         0   26      1      2      2      0      0
# 22591  22591     160000         0   41      0      0      0      0     -2
# 23104  23104      90000         0   42      0      0      2      0      0
# 24217  24217     180000         0   27     -2     -2     -2     -2     -2
# 28604  28604     110000         0   44      2      2      2      2      2
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# 8887       0  ...      2700      1500           0         1
# 22591     -1  ...       351         0           1         0
# 23104      0  ...      3000      2000           1         0
# 24217     -2  ...       155       209           0         1
# 28604      2  ...      1800      1800           1         0
#
#        EDUCATION_graduate school  EDUCATION_high school  EDUCATION_other  \
# 8887                           0                      1                0
# ...

# %%
credit_csv.loc[(credit_csv['MARRIAGE']==0) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 219      219     110000         0   31      0      0      0      0      0
# 810      810     160000         0   37      0      0      0      0      0
# 821      821     200000         0   51     -1     -1     -1     -1      0
# 1020    1020     180000         0   45     -1     -1     -2     -2     -2
# 1444    1444     200000         0   51     -1     -1     -1     -1      0
# 2147    2147     150000         0   55     -1     -1     -1     -1     -1
# 2555    2555     220000         0   33     -1     -1     -1     -1     -1
# 3057    3057     200000         0   36     -2     -2     -2     -2     -2
# 4471    4471      70000         0   35      2      2      2      2      2
# 5006    5006      90000         0   24     -2     -2     -2     -1      0
# 5346    5346      50000         0   28      1      2      0      0      0
# 6390    6390      10000         0   40      0      0      0      0      0
# ...

# %%
credit_csv.loc[(credit_csv['MARRIAGE']==1) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0          1      20000         1   24      2      2     -1     -1     -2
# 21        22     120000         1   39     -1     -1     -1     -1     -1
# 23        24     450000         1   40     -2     -2     -2     -2     -2
# 60        61     500000         1   28      0      0      0      0      0
# 63        64      50000         1   46      0      0      0     -2     -2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29975  29975      50000         1   37      1      2      2      2      0
# 29983  29983      90000         1   36      0      0      0      0      0
# 29992  29992     210000         1   34      3      2      2      2      2
# 29999  29999      80000         1   41      1     -1      0      0      0
# 30000  30000      50000         1   46      0      0      0      0      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['MARRIAGE']==1) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 3          4      50000         1   37      0      0      0      0      0
# 4          5      50000         1   57     -1      0     -1      0      0
# 8          9     140000         1   28      0      0      2      0      0
# 17        18     320000         1   49      0      0      0     -1     -1
# 18        19     360000         1   49      1     -2     -2     -2     -2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29984  29984      20000         1   44     -2     -2     -2     -2     -2
# 29989  29989     250000         1   34      0      0      0      0      0
# 29991  29991     140000         1   41      0      0      0      0      0
# 29993  29993      10000         1   43      0      0      0     -2     -2
# 29996  29996     220000         1   39      0      0      0      0      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['MARRIAGE']==2) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 1          2     120000         2   26     -1      2      0      0      0
# 13        14      70000         2   30      1      2      2      0      0
# 16        17      20000         2   24      0      0      2      2      2
# 22        23      70000         2   26      2      0      0      2      2
# 26        27      60000         2   27      1     -2     -1     -1     -1
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29945  29945      80000         2   39      3      2      0      0      0
# 29967  29967     150000         2   31      2      0      0      0     -2
# 29977  29977      40000         2   47      2      2      3      2      2
# 29995  29995      80000         2   34      2      2      2      2      2
# 29998  29998      30000         2   37      4      3      2     -1      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['MARRIAGE']==2) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 2          3      90000         2   34      0      0      0      0      0
# 5          6      50000         2   37      0      0      0      0      0
# 6          7     500000         2   29      0      0      0      0      0
# 7          8     100000         2   23      0     -1     -1      0      0
# 9         10      20000         2   35     -2     -2     -2     -2     -1
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29987  29987     360000         2   35     -1     -1     -2     -2     -2
# 29988  29988     130000         2   34      0      0      0      0      0
# 29990  29990     150000         2   35     -1     -1     -1     -1     -1
# 29994  29994     100000         2   38      0     -1     -1      0      0
# 29997  29997     150000         2   43     -1     -1     -1     -1      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['MARRIAGE']==3) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 240      240     140000         3   41      0      0      0      0      0
# 704      704      50000         3   30      1      3      2      0      0
# 848      848      50000         3   42      2      0      0      2      0
# 897      897     110000         3   55      1      2      2      2      3
# 899      899      90000         3   51      0      0      0      0      2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 28341  28341      20000         3   40     -1     -1     -1      2     -1
# 28737  28737     140000         3   28      0      0      0      0      0
# 29053  29053      10000         3   52      1      4      3      2      2
# 29203  29203      10000         3   22      0      0      0      0      0
# 29613  29613      20000         3   47     -1     -1      2      2     -1
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['MARRIAGE']==3) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 15        16      50000         3   23      1      2      0      0      0
# 51        52     100000         3   43      0      0      0      0      0
# 80        81     470000         3   33      0      0      0      0      0
# 374      374      30000         3   54      0      0      0      0      0
# 402      402      60000         3   42      0      0      0      0      0
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29220  29220      20000         3   25      0      0      0      0      0
# 29283  29283      80000         3   25      0     -1     -1     -1     -1
# 29510  29510     200000         3   41      0      0      0      2      2
# 29746  29746      20000         3   40      0      0      0     -1     -1
# 29932  29932      60000         3   41      0      0      0      0      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv['age_bins'] = pd.cut(x=credit_csv['AGE'], bins=[20, 30, 40, 50, 60, 70, 80], labels=[20, 30, 40, 50, 60, 70])

# %%
print(credit_csv['age_bins'])
# Out:
# 0        20
# 1        20
# 2        30
# 3        30
# 4        50
#          ..
# 29996    30
# 29997    40
# 29998    30
# 29999    40
# 30000    40
# Name: age_bins, Length: 30000, dtype: category
# Categories (6, int64): [20 < 30 < 40 < 50 < 60 < 70]

# %%
#From the data given, the most defaulters are from 50's to 70's compared to 20's to 40's
#33% defaulters in 70's vs 26% in 60's vs 25% in 50's vs 23% in 40's vs 22% in 20's vs 20% in 30's.

credit_csv.loc[(credit_csv['age_bins']==20) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0          1      20000         1   24      2      2     -1     -1     -2
# 1          2     120000         2   26     -1      2      0      0      0
# 13        14      70000         2   30      1      2      2      0      0
# 16        17      20000         2   24      0      0      2      2      2
# 22        23      70000         2   26      2      0      0      2      2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29901  29901      20000         2   29      0      0     -2     -2     -2
# 29905  29905      60000         2   30      0      0      0      0      0
# 29906  29906      50000         1   30      1      2      2      0      0
# 29908  29908     240000         2   29      0      0      2      2      2
# 29909  29909     140000         2   29     -2     -2     -2     -2     -2
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==20) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 6          7     500000         2   29      0      0      0      0      0
# 7          8     100000         2   23      0     -1     -1      0      0
# 8          9     140000         1   28      0      0      2      0      0
# 14        15     250000         2   29      0      0      0      0      0
# 15        16      50000         3   23      1      2      0      0      0
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29955  29955     180000         2   30      0      0      0      0      2
# 29957  29957     150000         2   30      0      0      0     -1      0
# 29961  29961      10000         1   29      0      0      0      0      0
# 29963  29963      50000         2   30      1     -1      2     -1     -1
# 29986  29986     240000         2   30     -2     -2     -2     -2     -2
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==30) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 21        22     120000         1   39     -1     -1     -1     -1     -1
# 23        24     450000         1   40     -2     -2     -2     -2     -2
# 31        32      50000         2   33      2      0      0      0      0
# 99       100      20000         1   38      0      0      0      0      0
# 120      121      50000         2   37      2      2      2      3      2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29975  29975      50000         1   37      1      2      2      2      0
# 29983  29983      90000         1   36      0      0      0      0      0
# 29992  29992     210000         1   34      3      2      2      2      2
# 29995  29995      80000         2   34      2      2      2      2      2
# 29998  29998      30000         2   37      4      3      2     -1      0
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==30) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 2          3      90000         2   34      0      0      0      0      0
# 3          4      50000         1   37      0      0      0      0      0
# 5          6      50000         2   37      0      0      0      0      0
# 9         10      20000         2   35     -2     -2     -2     -2     -1
# 10        11     200000         2   34      0      0      2      0      0
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29988  29988     130000         2   34      0      0      0      0      0
# 29989  29989     250000         1   34      0      0      0      0      0
# 29990  29990     150000         2   35     -1     -1     -1     -1     -1
# 29994  29994     100000         2   38      0     -1     -1      0      0
# 29996  29996     220000         1   39      0      0      0      0      0
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==40) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 47        48     150000         2   46      0      0     -1      0      0
# 50        51      70000         2   42      1      2      2      2      2
# 63        64      50000         1   46      0      0      0     -2     -2
# 79        80     240000         2   44      1     -2     -2     -2     -2
# 86        87     360000         1   45     -1     -1      2      0     -1
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29936  29936      50000         1   48      0      0      0     -1      0
# 29943  29943     130000         1   45     -1     -1     -1     -1     -1
# 29977  29977      40000         2   47      2      2      3      2      2
# 29999  29999      80000         1   41      1     -1      0      0      0
# 30000  30000      50000         1   46      0      0      0      0      0
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==40) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 12        13     630000         2   41     -1      0     -1     -1     -1
# 17        18     320000         1   49      0      0      0     -1     -1
# 18        19     360000         1   49      1     -2     -2     -2     -2
# 28        29      50000         1   47     -1     -1     -1     -1     -1
# 51        52     100000         3   43      0      0      0      0      0
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29982  29982      50000         1   44      1      2      2      2      0
# 29984  29984      20000         1   44     -2     -2     -2     -2     -2
# 29991  29991     140000         1   41      0      0      0      0      0
# 29993  29993      10000         1   43      0      0      0     -2     -2
# 29997  29997     150000         2   43     -1     -1     -1     -1      0
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==50) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 65        66     200000         1   57     -2     -2     -2     -1      2
# 66        67      10000         1   56      2      2      2      0      0
# 90        91     200000         1   53      2      2      2      2      2
# 128      129      50000         1   51      0      0      0      0      0
# 138      139      50000         1   51     -1     -1     -1     -1     -2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29168  29168      80000         2   54      0      0      0      0      0
# 29170  29170      20000         1   56      1      3      2      2      0
# 29171  29171      60000         2   53      1      2      0      0      0
# 29177  29177     240000         1   56      3      2      2     -2     -2
# 29181  29181     140000         1   60      2      2      0      0      0
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==50) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 4          5      50000         1   57     -1      0     -1      0      0
# 11        12     260000         2   51     -1     -1     -1     -1     -1
# 33        34     500000         1   54     -2     -2     -2     -2     -2
# 34        35     500000         1   58     -2     -2     -2     -2     -2
# 64        65     130000         1   51     -1     -1     -2     -2     -1
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29178  29178     150000         2   58      2      0      0      0      0
# 29179  29179      90000         2   60     -1     -1     -1      0      0
# 29182  29182     170000         1   57      0      0      0      0      0
# 29183  29183     280000         1   56     -2     -2     -2     -2     -2
# 29186  29186      50000         2   55      2      0      0      0      0
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==60) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 1030    1030      30000         1   67      2      2      0      0      2
# 1626    1626      20000         1   63      2      2      2      2      2
# 1992    1992     360000         2   65      1     -2     -2     -2     -2
# 2135    2135     160000         1   66      2      2      2      2      2
# 3258    3258     360000         1   65      1     -2     -2     -2     -2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 27541  27541     180000         1   65      0     -1      0      0      0
# 29085  29085     260000         1   65     -2     -2     -2     -2     -2
# 29146  29146     230000         1   70     -1      0      0      0      0
# 29151  29151     360000         1   61      2      0      0      0      0
# 29153  29153     120000         1   61      1      2      0      0      0
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==60) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 102      103     480000         1   63      0      0      0      2      2
# 367      367      50000         1   61      0      0      0      0      0
# 1059    1059      80000         1   67      0      0      0      0      0
# 1071    1071     230000         1   61     -1     -1     -1     -1     -1
# 1074    1074     360000         1   66     -1     -1     -1     -1     -1
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29087  29087      60000         1   61      0      0      0      0      0
# 29129  29129     230000         1   66     -2     -2     -2     -2     -2
# 29150  29150      30000         1   67      2      2      2      0      0
# 29172  29172     510000         1   61      0      0      0      2      0
# 29174  29174     360000         1   64     -2     -2     -2     -2     -1
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==70) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 388      388      80000         1   73     -1      0      0      2      2
# 1645    1645      50000         1   72      2      0      0      0      2
# 25137  25137     180000         1   75      1     -2     -2     -2     -2
# 29164  29164     360000         1   73     -2     -2     -2     -2     -2
# 29180  29180     500000         1   73     -2     -2     -2     -2     -2
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# 388        2  ...      5100           0         1                          0
# 1645       2  ...         0           0         1                          0
# 25137     -2  ...         0           0         1                          1
# 29164     -2  ...         0           1         0                          0
# 29180     -2  ...       711           1         0                          0
#
# ...

# %%
credit_csv.loc[(credit_csv['age_bins']==70) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 247      247     250000         1   75      0     -1     -1     -1     -1
# 2105    2105     250000         1   71      0      0      0      0      0
# 6024    6024      70000         1   71      0      0      0      2      0
# 10700  10700     140000         1   73      0      0      0      0      0
# 18246  18246     440000         1   79      0      0      0      0      0
# 20265  20265     150000         1   72     -2     -2     -2     -2     -2
# 25142  25142     210000         1   75      0      0      0      0      0
# 25143  25143     300000         1   72     -1     -1     -1     -1     -1
# 27542  27542     250000         1   71      0      0      0      0      0
# 29176  29176     160000         1   74      0      0      0     -1     -1
#
#        PAY_6  ...  PAY_AMT6  SEX_female  SEX_male  EDUCATION_graduate school  \
# ...

# %%
credit_csv.groupby('EDUCATION_other').count()
# Out:
#                     ID  LIMIT_BAL  MARRIAGE    AGE  PAY_0  PAY_2  PAY_3  \
# EDUCATION_other
# 0                29532      29532     29532  29532  29532  29532  29532
# 1                  468        468       468    468    468    468    468
#
#                  PAY_4  PAY_5  PAY_6  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# EDUCATION_other                       ...
# 0                29532  29532  29532  ...     29532     29532     29532
# 1                  468    468    468  ...       468       468       468
#
#                  SEX_female  SEX_male  EDUCATION_graduate school  \
# EDUCATION_other
# 0                     29532     29532                      29532
# 1                       468       468                        468
#
#                  EDUCATION_high school  EDUCATION_university  \
# EDUCATION_other
# 0                                29532                 29532
# 1                                  468                   468
#
# ...

# %%
credit_csv.groupby('EDUCATION_graduate school').count()
# Out:
#                               ID  LIMIT_BAL  MARRIAGE    AGE  PAY_0  PAY_2  \
# EDUCATION_graduate school
# 0                          19415      19415     19415  19415  19415  19415
# 1                          10585      10585     10585  10585  10585  10585
#
#                            PAY_3  PAY_4  PAY_5  PAY_6  ...  PAY_AMT4  \
# EDUCATION_graduate school                              ...
# 0                          19415  19415  19415  19415  ...     19415
# 1                          10585  10585  10585  10585  ...     10585
#
#                            PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# EDUCATION_graduate school
# 0                             19415     19415       19415     19415
# 1                             10585     10585       10585     10585
#
#                            EDUCATION_high school  EDUCATION_other  \
# EDUCATION_graduate school
# 0                                          19415            19415
# ...

# %%
credit_csv.groupby('EDUCATION_university').count()
# Out:
#                          ID  LIMIT_BAL  MARRIAGE    AGE  PAY_0  PAY_2  PAY_3  \
# EDUCATION_university
# 0                     15970      15970     15970  15970  15970  15970  15970
# 1                     14030      14030     14030  14030  14030  14030  14030
#
#                       PAY_4  PAY_5  PAY_6  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# EDUCATION_university                       ...
# 0                     15970  15970  15970  ...     15970     15970     15970
# 1                     14030  14030  14030  ...     14030     14030     14030
#
#                       SEX_female  SEX_male  EDUCATION_graduate school  \
# EDUCATION_university
# 0                          15970     15970                      15970
# 1                          14030     14030                      14030
#
#                       EDUCATION_high school  EDUCATION_other  \
# EDUCATION_university
# 0                                     15970            15970
# ...

# %%
credit_csv.groupby('EDUCATION_high school').count()
# Out:
#                           ID  LIMIT_BAL  MARRIAGE    AGE  PAY_0  PAY_2  PAY_3  \
# EDUCATION_high school
# 0                      25083      25083     25083  25083  25083  25083  25083
# 1                       4917       4917      4917   4917   4917   4917   4917
#
#                        PAY_4  PAY_5  PAY_6  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# EDUCATION_high school                       ...
# 0                      25083  25083  25083  ...     25083     25083     25083
# 1                       4917   4917   4917  ...      4917      4917      4917
#
#                        SEX_female  SEX_male  EDUCATION_graduate school  \
# EDUCATION_high school
# 0                           25083     25083                      25083
# 1                            4917      4917                       4917
#
#                        EDUCATION_other  EDUCATION_university  \
# EDUCATION_high school
# 0                                25083                 25083
# ...

# %%
#The proportion of high school defaulters is more compared to all other defaulters.
#25% high school defaulters vs 23% university defaulters vs 19% graduate school defaulters vs 7% other defaulters.

credit_csv.loc[(credit_csv['EDUCATION_other']==1) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 47        48     150000         2   46      0      0     -1      0      0
# 2670    2670      10000         1   43     -1      0      0      0     -2
# 3990    3990     100000         1   52      0      0      0      0      0
# 4727    4727      50000         2   42      0      0      0      0      0
# 6529    6529      90000         2   23      0      0      0      0      0
# 9915    9915     220000         1   37      2      2      2      0      0
# 10733  10733     260000         2   32      0      0      0      0      0
# 11770  11770     130000         1   44      0      0      0      0      0
# 12836  12836     120000         1   39      2      0      0      0      0
# 14279  14279      50000         1   33      2      0     -1      2      0
# 15227  15227     130000         1   44      2      2      2      2      0
# 18340  18340      20000         2   22      0      0      0      0      0
# ...

# %%
credit_csv.loc[(credit_csv['EDUCATION_other']==1) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 69        70      20000         2   22      2      0      0      0      0
# 359      359     110000         2   24      0      0      0      0      0
# 386      386     410000         1   42      0      0      0      0      0
# 449      449     200000         1   42      0      0      0      0      0
# 503      503     230000         2   46      0      0      0      0      0
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29611  29611     220000         1   37     -2     -2     -1     -1     -1
# 29812  29812      50000         2   46      0      0      0     -1      0
# 29837  29837     180000         1   34     -2     -2     -2     -2     -2
# 29840  29840     150000         1   36      0      0      0      0      0
# 29848  29848     310000         1   46     -1     -1     -1     -1     -1
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['EDUCATION_graduate school']==1) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 16        17      20000         2   24      0      0      2      2      2
# 23        24     450000         1   40     -2     -2     -2     -2     -2
# 26        27      60000         2   27      1     -2     -1     -1     -1
# 38        39      50000         2   25      1     -1     -1     -2     -2
# 45        46     210000         2   29     -2     -2     -2     -2     -2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29900  29900     140000         2   29      0      0      0      0      0
# 29908  29908     240000         2   29      0      0      2      2      2
# 29909  29909     140000         2   29     -2     -2     -2     -2     -2
# 29918  29918      30000         2   33     -1      3      2     -1      0
# 29922  29922     410000         2   34      0      0      0     -1     -1
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['EDUCATION_graduate school']==1) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 5          6      50000         2   37      0      0      0      0      0
# 6          7     500000         2   29      0      0      0      0      0
# 11        12     260000         2   51     -1     -1     -1     -1     -1
# 14        15     250000         2   29      0      0      0      0      0
# 17        18     320000         1   49      0      0      0     -1     -1
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29987  29987     360000         2   35     -1     -1     -2     -2     -2
# 29988  29988     130000         2   34      0      0      0      0      0
# 29989  29989     250000         1   34      0      0      0      0      0
# 29990  29990     150000         2   35     -1     -1     -1     -1     -1
# 29994  29994     100000         2   38      0     -1     -1      0      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['EDUCATION_university']==1) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0          1      20000         1   24      2      2     -1     -1     -2
# 1          2     120000         2   26     -1      2      0      0      0
# 13        14      70000         2   30      1      2      2      0      0
# 21        22     120000         1   39     -1     -1     -1     -1     -1
# 22        23      70000         2   26      2      0      0      2      2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29983  29983      90000         1   36      0      0      0      0      0
# 29992  29992     210000         1   34      3      2      2      2      2
# 29995  29995      80000         2   34      2      2      2      2      2
# 29998  29998      30000         2   37      4      3      2     -1      0
# 30000  30000      50000         1   46      0      0      0      0      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['EDUCATION_university']==1) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 2          3      90000         2   34      0      0      0      0      0
# 3          4      50000         1   37      0      0      0      0      0
# 4          5      50000         1   57     -1      0     -1      0      0
# 7          8     100000         2   23      0     -1     -1      0      0
# 12        13     630000         2   41     -1      0     -1     -1     -1
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29979  29979     310000         1   39      0      0      0      0      0
# 29982  29982      50000         1   44      1      2      2      2      0
# 29984  29984      20000         1   44     -2     -2     -2     -2     -2
# 29985  29985      30000         2   38     -1     -1     -2     -1     -1
# 29991  29991     140000         1   41      0      0      0      0      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['EDUCATION_high school']==1) & (credit_csv['default payment next month_default']==1)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 50        51      70000         2   42      1      2      2      2      2
# 60        61     500000         1   28      0      0      0      0      0
# 82        83      60000         2   30      0      0      0      0      0
# 103      104      50000         2   22      0      0      0      0      0
# 120      121      50000         2   37      2      2      2      3      2
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29920  29920      50000         1   37     -1     -1      2      2     -1
# 29930  29930     170000         1   46     -1     -1     -1     -1     -1
# 29933  29933     160000         1   42      2      0      0      0      0
# 29943  29943     130000         1   45     -1     -1     -1     -1     -1
# 29999  29999      80000         1   41      1     -1      0      0      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
credit_csv.loc[(credit_csv['EDUCATION_high school']==1) & (credit_csv['default payment next month_default']==0)]
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 8          9     140000         1   28      0      0      2      0      0
# 9         10      20000         2   35     -2     -2     -2     -2     -1
# 10        11     200000         2   34      0      0      2      0      0
# 15        16      50000         3   23      1      2      0      0      0
# 20        21     130000         2   39      0      0      0      0      0
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29972  29972      80000         1   36      0      0      0      0      0
# 29981  29981      50000         2   42      0      0      0      0      0
# 29993  29993      10000         1   43      0      0      0     -2     -2
# 29996  29996     220000         1   39      0      0      0      0      0
# 29997  29997     150000         2   43     -1     -1     -1     -1      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# ...

# %%
#There are defaulters all in all until 800K credit limit but above that there are no defaulters.

x = credit_csv['LIMIT_BAL']
y = credit_csv['default payment next month_default']
plt.scatter(x,y)
plt.show()

# %%
#There are defaulters in all age groups.

x = credit_csv['AGE']
y = credit_csv['default payment next month_default']
plt.scatter(x,y)
plt.show()

# %%
#There are defaulters in all marital status.

x = credit_csv['MARRIAGE']
y = credit_csv['default payment next month_default']
plt.scatter(x,y)
plt.show()

# %%
#There are defaulters in both the SEX.

x = credit_csv['SEX_female']
y = credit_csv['default payment next month_default']
plt.scatter(x,y)
plt.show()

# %%
#There are defaulters in EDUCATION_graduate school.

x = credit_csv['EDUCATION_graduate school']
y = credit_csv['default payment next month_default']
plt.scatter(x,y)
plt.show()

# %%
#There are defaulters in EDUCATION_high school

x = credit_csv['EDUCATION_high school']
y = credit_csv['default payment next month_default']
plt.scatter(x,y)
plt.show()

# %%
#There are defaulters in EDUCATION_graduate school

x = credit_csv['EDUCATION_other']
y = credit_csv['default payment next month_default']
plt.scatter(x,y)
plt.show()

# %%
#There are defaulters in EDUCATION_university 

x = credit_csv['EDUCATION_university']
y = credit_csv['default payment next month_default']
plt.scatter(x,y)
plt.show()

# %%
#less defaulters in the month of April and there by increasing until september which has the highest defaulters.

corrMat = credit_csv.corr()
print(corrMat)
# Out:
#                                               ID  LIMIT_BAL  MARRIAGE  \
# ID                                      1.000000   0.026179 -0.029079
# LIMIT_BAL                               0.026179   1.000000 -0.108139
# MARRIAGE                               -0.029079  -0.108139  1.000000
# AGE                                     0.018678   0.144713 -0.414170
# PAY_0                                  -0.030575  -0.271214  0.019917
# PAY_2                                  -0.011215  -0.296382  0.024199
# PAY_3                                  -0.018494  -0.286123  0.032688
# PAY_4                                  -0.002735  -0.267460  0.033122
# PAY_5                                  -0.022199  -0.249411  0.035629
# PAY_6                                  -0.020270  -0.235195  0.034345
# BILL_AMT1                               0.019389   0.285430 -0.023472
# BILL_AMT2                               0.017982   0.278314 -0.021602
# ...
